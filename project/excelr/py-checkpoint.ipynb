# %% [markdown]
# # 1. Initialize

# %% [markdown]
# ## Getting Data

# %%
import pycaret

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\Raja\\Downloads\\assignments\\multi linear\\50_Startups.csv')

# %%
df.head()
# Out:
#      RDSpend  Administration  MarketingSpend       State     Profit
# 0  165349.20       136897.80       471784.10    New York  192261.83
# 1  162597.70       151377.59       443898.53  California  191792.06
# 2  153441.51       101145.55       407934.54     Florida  191050.39
# 3  144372.41       118671.85       383199.62    New York  182901.99
# 4  142107.34        91391.77       366168.42     Florida  166187.94

# %%
df.size
# Out:
# 250

# %% [markdown]
# ## Setting up Environment

# %%
from pycaret.regression import *
env= setup(data = df, target = 'Profit')
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_8c87e3b4_9759_11ea_84e7_34e6ad71bcfe" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8c87e3b4_9759_11ea_84e7_34e6ad71bcfelevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8c87e3b4_9759_11ea_84e7_34e6ad71bcferow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_8c87e3b4_9759_11ea_84e7_34e6ad71bcferow0_col1" class="data row0 col1" >470</td>
#             </tr>
#             <tr>
#                         <th id="T_8c87e3b4_9759_11ea_84e7_34e6ad71bcfelevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8c87e3b4_9759_11ea_84e7_34e6ad71bcferow1_col0" class="data row1 col0" >Transform Target </td>
# ...

# %% [markdown]
# # 2. Model Training

# %% [markdown]
# ## Compare Models

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_9eacdea4_9759_11ea_9812_34e6ad71bcfe th {
#           text-align: left;
#     }    #T_9eacdea4_9759_11ea_9812_34e6ad71bcferow0_col0 {
#             text-align:  left;
#         }    #T_9eacdea4_9759_11ea_9812_34e6ad71bcferow0_col1 {
#             : ;
#             text-align:  left;
#         }    #T_9eacdea4_9759_11ea_9812_34e6ad71bcferow0_col2 {
#             : ;
#             text-align:  left;
#         }    #T_9eacdea4_9759_11ea_9812_34e6ad71bcferow0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_9eacdea4_9759_11ea_9812_34e6ad71bcferow0_col4 {
#             text-align:  left;
#         }    #T_9eacdea4_9759_11ea_9812_34e6ad71bcferow0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_9eacdea4_9759_11ea_9812_34e6ad71bcferow0_col6 {
#             : ;
#             text-align:  left;
#         }    #T_9eacdea4_9759_11ea_9812_34e6ad71bcferow1_col0 {
#             text-align:  left;
# ...

# %% [markdown]
# ## Create Model

# %%
lr = create_model('lr')
# Out:
#              MAE           MSE        RMSE      R2   RMSLE    MAPE
# 0      7625.7416  7.593209e+07   8713.9023  0.9534  0.0754  0.0665
# 1      9014.0314  1.315948e+08  11471.4756  0.8482  0.1943  0.1122
# 2      6472.9968  8.045950e+07   8969.9221  0.9819  0.1865  0.1270
# 3      5195.3902  4.646034e+07   6816.1823  0.9759  0.1122  0.0803
# 4      5579.6966  4.057304e+07   6369.6967  0.8290  0.0511  0.0444
# 5      4299.2051  4.079046e+07   6386.7411  0.9582  0.0491  0.0356
# 6      7539.7673  6.281400e+07   7925.5284  0.8044  0.0776  0.0767
# 7     13824.0683  4.297264e+08  20729.8439  0.8711  0.7110  0.8223
# 8     16898.0839  2.893624e+08  17010.6569  0.3486  0.1823  0.1710
# 9      4214.6907  1.946865e+07   4412.3288  0.9873  0.0375  0.0347
# Mean   8066.3672  1.217182e+08   9880.6278  0.8558  0.1677  0.1571
# SD     3981.3523  1.263298e+08   4908.2955  0.1813  0.1899  0.2255

# %%
et=create_model('et')
# Out:
#              MAE           MSE        RMSE      R2   RMSLE    MAPE
# 0      8256.3643  1.387072e+08  11777.4032  0.9149  0.3845  0.1557
# 1     10255.3131  1.916685e+08  13844.4392  0.7789  0.2581  0.1321
# 2     12306.3965  1.921351e+08  13861.2805  0.9568  0.2246  0.1833
# 3      9020.6970  9.955473e+07   9977.7115  0.9483  0.1361  0.1111
# 4      3242.5592  1.896456e+07   4354.8319  0.9201  0.0364  0.0265
# 5      3163.1279  1.175749e+07   3428.9191  0.9879  0.0336  0.0319
# 6      5289.9757  2.841314e+07   5330.3978  0.9115  0.0553  0.0555
# 7     13295.5143  3.587765e+08  18941.3973  0.8924  0.6723  0.7536
# 8     14534.9381  2.221360e+08  14904.2277  0.4999  0.1484  0.1440
# 9      6642.4406  6.109519e+07   7816.3410  0.9602  0.0533  0.0466
# Mean   8600.7327  1.323208e+08  10423.6949  0.8771  0.2003  0.1641
# SD     3835.2822  1.052703e+08   4864.9183  0.1368  0.1910  0.2035

# %%
br=create_model('br')
# Out:
#              MAE           MSE        RMSE      R2   RMSLE    MAPE
# 0      5419.8008  3.057105e+07   5529.1094  0.9812  0.0605  0.0597
# 1      8968.9910  1.412595e+08  11885.2650  0.8371  0.1948  0.1093
# 2      6789.0574  7.542642e+07   8684.8387  0.9830  0.1724  0.1240
# 3      4993.8958  4.023432e+07   6343.0531  0.9791  0.1034  0.0752
# 4      5712.3028  4.734096e+07   6880.4769  0.8005  0.0569  0.0456
# 5      4742.5629  5.034033e+07   7095.0919  0.9484  0.0529  0.0363
# 6      5072.8899  3.500491e+07   5916.4945  0.8910  0.0532  0.0488
# 7     13911.8477  4.490753e+08  21191.3971  0.8653  0.7199  0.8383
# 8     17027.8113  2.907965e+08  17052.7553  0.3453  0.1897  0.1744
# 9      2146.4362  7.260424e+06   2694.5174  0.9953  0.0244  0.0195
# Mean   7478.5596  1.167310e+08   9327.2999  0.8626  0.1628  0.1531
# SD     4364.7265  1.357277e+08   5452.7468  0.1844  0.1951  0.2327

# %% [markdown]
# # 3. Tune Model

# %%
tuned_lr = tune_model('lr')
tuned_lr
# Out:
#              MAE           MSE        RMSE      R2   RMSLE    MAPE
# 0      7625.7416  7.593209e+07   8713.9023  0.9534  0.0754  0.0665
# 1      9014.0314  1.315948e+08  11471.4756  0.8482  0.1943  0.1122
# 2      6472.9968  8.045950e+07   8969.9221  0.9819  0.1865  0.1270
# 3      5195.3902  4.646034e+07   6816.1823  0.9759  0.1122  0.0803
# 4      5579.6966  4.057304e+07   6369.6967  0.8290  0.0511  0.0444
# 5      4299.2051  4.079046e+07   6386.7411  0.9582  0.0491  0.0356
# 6      7539.7673  6.281400e+07   7925.5284  0.8044  0.0776  0.0767
# 7     13824.0683  4.297264e+08  20729.8439  0.8711  0.7110  0.8223
# 8     16898.0839  2.893624e+08  17010.6569  0.3486  0.1823  0.1710
# 9      4214.6907  1.946865e+07   4412.3288  0.9873  0.0375  0.0347
# Mean   8066.3672  1.217182e+08   9880.6278  0.8558  0.1677  0.1571
# SD     3981.3523  1.263298e+08   4908.2955  0.1813  0.1899  0.2255
# LinearRegression(copy_X=True, fit_intercept=False, n_jobs=None, normalize=True)

# %%
tuned_et = tune_model('et')
tuned_et
# Out:
#              MAE           MSE        RMSE      R2   RMSLE    MAPE
# 0      7108.5212  8.711372e+07   9333.4734  0.9465  0.1721  0.1262
# 1      6141.9024  6.494369e+07   8058.7646  0.9251  0.0885  0.0633
# 2     24215.1544  6.990803e+08  26440.1273  0.8427  0.3008  0.2830
# 3      9613.0134  1.451250e+08  12046.7837  0.9246  0.1864  0.1404
# 4      8043.6843  7.435049e+07   8622.6733  0.6867  0.0747  0.0676
# 5      7494.8742  8.253928e+07   9085.1129  0.9154  0.0954  0.0798
# 6      6663.5548  4.596958e+07   6780.0869  0.8568  0.0705  0.0709
# 7     18369.7161  7.612906e+08  27591.4957  0.7716  0.8335  1.0975
# 8     10615.4539  1.335879e+08  11558.0223  0.6993  0.1031  0.1009
# 9     13365.1885  4.025774e+08  20064.3314  0.7380  0.1165  0.0771
# Mean  11163.1063  2.496578e+08  13958.0871  0.8307  0.2041  0.2107
# SD     5611.8437  2.592725e+08   7404.7014  0.0945  0.2201  0.3021
# ExtraTreesRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mae',
# ...

# %%
tuned_br = tune_model('br')
tuned_br
# Out:
#              MAE           MSE        RMSE      R2   RMSLE    MAPE
# 0      5424.9114  3.078144e+07   5548.1025  0.9811  0.0601  0.0593
# 1      8958.5989  1.413664e+08  11889.7600  0.8369  0.1955  0.1094
# 2      6797.3596  7.535896e+07   8680.9537  0.9830  0.1729  0.1244
# 3      4999.2312  3.814946e+07   6176.5247  0.9802  0.0997  0.0735
# 4      5592.0149  4.577759e+07   6765.9136  0.8071  0.0558  0.0445
# 5      4738.2543  5.008843e+07   7077.3181  0.9486  0.0528  0.0365
# 6      5060.9547  3.445338e+07   5869.7003  0.8927  0.0530  0.0488
# 7     13922.6296  4.477277e+08  21159.5761  0.8657  0.7191  0.8370
# 8     17093.0720  2.930395e+08  17118.3967  0.3403  0.1905  0.1751
# 9      2182.0785  7.493816e+06   2737.4834  0.9951  0.0247  0.0197
# Mean   7476.9105  1.164237e+08   9302.3729  0.8631  0.1624  0.1528
# SD     4381.2076  1.359049e+08   5467.1310  0.1857  0.1951  0.2324
# BayesianRidge(alpha_1=0.3, alpha_2=0.15, alpha_init=None, compute_score=True,
# ...

# %% [markdown]
# # 4. Model Ensembling

# %% [markdown]
# ## Blend Models

# %%
blender = blend_models(estimator_list = [lr, et, br])
blender
# Out:
#              MAE           MSE        RMSE      R2   RMSLE    MAPE
# 0      6424.2232  4.144277e+07   6437.6062  0.9746  0.0929  0.0781
# 1      8999.5518  1.492306e+08  12215.9991  0.8279  0.2136  0.1133
# 2      8318.7230  1.058211e+08  10286.9385  0.9762  0.1942  0.1437
# 3      5542.8792  4.750976e+07   6892.7327  0.9753  0.1146  0.0832
# 4      4308.6529  2.840371e+07   5329.5130  0.8803  0.0440  0.0344
# 5      3522.2304  2.940862e+07   5422.9713  0.9698  0.0399  0.0264
# 6      4985.4840  3.510014e+07   5924.5370  0.8907  0.0533  0.0466
# 7     13108.4968  4.064290e+08  20160.0831  0.8781  0.7012  0.8009
# 8     16153.6111  2.650887e+08  16281.5451  0.4032  0.1729  0.1631
# 9      4046.6662  2.000406e+07   4472.5900  0.9870  0.0352  0.0312
# Mean   7541.0519  1.128438e+08   9342.4516  0.8763  0.1662  0.1521
# SD     3981.0250  1.220105e+08   5055.9316  0.1664  0.1893  0.2210
# VotingRegressor(estimators=[('Linear Regression_0',
# ...

# %% [markdown]
# # 5. Model Analysis

# %% [markdown]
# ## Plot Model

# %%
plot_model(br, plot='error')

# %%
plot_model(br, plot='rfe')
